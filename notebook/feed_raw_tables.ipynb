# %%
# Diagonosis mapping

df = spark.read.option("header", "true").option("inferSchema", "true").csv("/Volumes/atabricks_bootcamp/default/healthcare_data/diagnosis_mapping.csv")
display(df)

df.write.format("delta").mode("append").saveAsTable("atabricks_bootcamp.default.raw_diagnosis_map")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>diagnosis_code</th><th>diagnosis_description</th></tr></thead><tbody><tr><td>D001</td><td>Hypertension</td></tr><tr><td>D002</td><td>Diabetes Mellitus</td></tr><tr><td>D003</td><td>Chronic Obstructive Pulmonary Disease</td></tr><tr><td>D004</td><td>Asthma</td></tr><tr><td>D005</td><td>Heart Failure</td></tr><tr><td>D006</td><td>Stroke</td></tr><tr><td>D007</td><td>Myocardial Infarction</td></tr><tr><td>D008</td><td>Chronic Kidney Disease</td></tr><tr><td>D009</td><td>Hyperlipidemia</td></tr><tr><td>D010</td><td>Coronary Artery Disease</td></tr></tbody></table></div>

# %%
#path = "/Volumes/atabricks_bootcamp/default/healthcare_data/patients_daily_file_1_2025.csv"
#path = "/Volumes/atabricks_bootcamp/default/healthcare_data/patients_daily_file_2_2025.csv"
path = "/Volumes/atabricks_bootcamp/default/healthcare_data/patients_daily_file_3_2025.csv"

df = spark.read.option("header", "true").option("inferSchema", "true").csv(f"{path}")
df = df.withColumn("admission_date", df["admission_date"].cast("date"))

display(df)

df.write.format("delta").option("mergeSchema", "true").mode("append").saveAsTable("atabricks_bootcamp.default.raw_patients_daily")
# Out:
# ---------------------------------------------------------------------------
# DateTimeException                         Traceback (most recent call last)
# File <command-4586847799988784>, line 8
#       5 df = spark.read.option("header", "true").option("inferSchema", "true").csv(f"{path}")
#       6 df = df.withColumn("admission_date", df["admission_date"].cast("date"))
# ----> 8 display(df)
#      10 df.write.format("delta").option("mergeSchema", "true").mode("append").saveAsTable("atabricks_bootcamp.default.raw_patients_daily")
#
# File /databricks/python_shell/lib/dbruntime/display.py:136, in Display.display(self, input, *args, **kwargs)
#     134     pass
#     135 elif self._cf_helper is not None and isinstance(input, ConnectDataFrame):
# --> 136     self.display_connect_table(input, **kwargs)
#     137 elif isinstance(input, ConnectDataFrame):
#     138     if input.isStreaming:
#
# ...

# %%
# %sql
select count(*) from atabricks_bootcamp.default.raw_patients_daily
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(*)</th></tr></thead><tbody><tr><td>400</td></tr></tbody></table></div>
